# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # <center> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ####  **Lewis Arboit**
#
# Student

# %% [markdown]
# ###### *I am interested in data science because it is a fascinating field and I believe will creatively challenge me*

# %% [markdown]
# ### The code below outlines the simple multiplication of a x b, where a = 2 and b = 8

# %%
a = 2 
b = 8 

print (a * b)
# Out:
# 16

# %% [markdown]
# ##### (1) Numbered list example
#
# 1. One
# 2. two
# 3. three
#
# ##### (2) Table example
#
# | Column 1      | Column 2      | Column 3|
# | ------------- |:-------------:| -----  :|
# | Row    1        |               |         |
# | Row 2         |                |        |
#
# ##### (3) Hyperlink example
#
# *Link to website:* https://www.bbc.com/news
#
# ##### (4) Image example
#
# ![image.png](attachment:15ddcad3-9fde-486a-94eb-8be1007c739d.png)
#
# ##### (5) Blocked quote example
#
# > Hi, what's your name?
# > My name is Lewis.
